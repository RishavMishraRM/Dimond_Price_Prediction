# %% [markdown]
# Introduction About the Data :
# The dataset The goal is to predict price of given diamond (Regression Analysis).
#
# There are 10 independent variables (including id):
#
# id : unique identifier of each diamond <br>
# carat : Carat (ct.) refers to the unique unit of weight measurement used exclusively to weigh gemstones and diamonds. <br>
# cut : Quality of Diamond Cut <br>
# color : Color of Diamond <br>
# clarity : Diamond clarity is a measure of the purity and rarity of the stone, graded by the visibility of these characteristics under 10-power magnification. <br>
# depth : The depth of diamond is its height (in millimeters) measured from the culet (bottom tip) to the table (flat, top surface) <br>
# table : A diamond's table is the facet which can be seen when the stone is viewed face up. <br>
# x : Diamond X dimension <br>
# y : Diamond Y dimension <br>
# x : Diamond Z dimension <br>
# Target variable:
#
# price: Price of the given Diamond.
# Dataset Source Link : https://www.kaggle.com/competitions/playground-series-s3e8/data?select=train.csv

# %% [markdown]
# 1. Ingest the data

# %%
import pandas as pd

# %%
data = pd.read_csv('data/gemstone.csv')

# %%
data.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.tail()
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 193568  193568   0.31      Ideal     D    VVS2   61.1   56.0  4.35  4.39
# 193569  193569   0.70    Premium     G    VVS2   60.3   58.0  5.75  5.77
# 193570  193570   0.73  Very Good     F     SI1   63.1   57.0  5.72  5.75
# 193571  193571   0.34  Very Good     D     SI1   62.9   55.0  4.45  4.49
# 193572  193572   0.71       Good     E     SI2   60.8   64.0  5.73  5.71
#
#            z  price
# 193568  2.67   1130
# 193569  3.47   2874
# 193570  3.62   3036
# 193571  2.81    681
# 193572  3.48   2258

# %%
data.sample(5)
# Out:
#             id  carat        cut color clarity  depth  table     x     y  \
# 143546  143546   0.32       Good     G     VS2   63.7   56.0  4.31  4.33
# 52179    52179   0.72      Ideal     F     SI1   61.7   57.0  5.75  5.77
# 45181    45181   0.39  Very Good     E     VS2   60.5   62.0  4.70  4.73
# 116884  116884   1.20  Very Good     G     SI2   61.3   56.0  6.78  6.73
# 24751    24751   1.02      Ideal     G      IF   61.2   58.0  6.49  6.54
#
#            z  price
# 143546  2.75    561
# 52179   3.55   2749
# 45181   2.84    839
# 116884  4.15   5490
# 24751   3.99   8699

# %%
data.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193573 entries, 0 to 193572
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   id       193573 non-null  int64
#  1   carat    193573 non-null  float64
#  2   cut      193573 non-null  object
#  3   color    193573 non-null  object
#  4   clarity  193573 non-null  object
#  5   depth    193573 non-null  float64
#  6   table    193573 non-null  float64
#  7   x        193573 non-null  float64
#  8   y        193573 non-null  float64
#  9   z        193573 non-null  float64
#  10  price    193573 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 16.2+ MB

# %%
data = data.drop(labels=['id'], axis=1)

# %%
data.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.shape
# Out:
# (193573, 10)

# %%
data.dtypes
# Out:
# carat      float64
# cut         object
# color       object
# clarity     object
# depth      float64
# table      float64
# x          float64
# y          float64
# z          float64
# price        int64
# dtype: object

# %% [markdown]
# https://www.vrai.com/journal/post/diamond-cut
#
# ![image.png](attachment:image.png)

# %%
categorical_columns = data.columns[data.dtypes=="object"]

# %%
numerical_columns = data.columns[data.dtypes!="object"]

# %%
data[categorical_columns].describe()
# Out:
#            cut   color clarity
# count   193573  193573  193573
# unique       5       7       8
# top      Ideal       G     SI1
# freq     92454   44391   53272

# %%
data[categorical_columns]["cut"].value_counts()
# Out:
# cut
# Ideal        92454
# Premium      49910
# Very Good    37566
# Good         11622
# Fair          2021
# Name: count, dtype: int64

# %%
data[categorical_columns]["color"].value_counts()
# Out:
# color
# G    44391
# E    35869
# F    34258
# H    30799
# D    24286
# I    17514
# J     6456
# Name: count, dtype: int64

# %%
data[categorical_columns]["clarity"].value_counts()
# Out:
# clarity
# SI1     53272
# VS2     48027
# VS1     30669
# SI2     30484
# VVS2    15762
# VVS1    10628
# IF       4219
# I1        512
# Name: count, dtype: int64

# %%
data[numerical_columns].describe().T
# Out:
#           count         mean          std    min     25%      50%      75%  \
# carat  193573.0     0.790688     0.462688    0.2    0.40     0.70     1.03
# depth  193573.0    61.820574     1.081704   52.1   61.30    61.90    62.40
# table  193573.0    57.227675     1.918844   49.0   56.00    57.00    58.00
# x      193573.0     5.715312     1.109422    0.0    4.70     5.70     6.51
# y      193573.0     5.720094     1.102333    0.0    4.71     5.72     6.51
# z      193573.0     3.534246     0.688922    0.0    2.90     3.53     4.03
# price  193573.0  3969.155414  4034.374138  326.0  951.00  2401.00  5408.00
#
#             max
# carat      3.50
# depth     71.60
# table     79.00
# x          9.65
# y         10.01
# z         31.30
# price  18818.00

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

for col in numerical_columns:
    sns.histplot(data=data, x=col, kde=True)
    print("\n")
    plt.show()

# %% [markdown]
# categorical data <br>
# assignment is to take all the categorical col and you need to plot either bar plot or count

# %%
sns.heatmap(data[numerical_columns].corr(), annot=True)
# Out:
# <Axes: >

# %%
# encoding
data['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
data['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
data['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
# oridinal encoding
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}
clarity_map = {"I1":1,"SI2":2 ,"SI1":3 ,"VS2":4 , "VS1":5 , "VVS2":6 , "VVS1":7 ,"IF":8}
color_map = {"D":1 ,"E":2 ,"F":3 , "G":4 ,"H":5 , "I":6, "J":7}

# %%
data["cut"]=data["cut"].map(cut_map)
data["clarity"]=data["clarity"].map(clarity_map)
data["color"]=data["color"].map(color_map)

# %%
data
# Out:
#         carat  cut  color  clarity  depth  table     x     y     z  price
# 0        1.52    4      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1        2.03    3      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2        0.70    5      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3        0.32    5      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4        1.70    4      4        4   62.6   59.0  7.65  7.61  4.77  14453
# ...       ...  ...    ...      ...    ...    ...   ...   ...   ...    ...
# 193568   0.31    5      1        6   61.1   56.0  4.35  4.39  2.67   1130
# 193569   0.70    4      4        6   60.3   58.0  5.75  5.77  3.47   2874
# 193570   0.73    3      3        3   63.1   57.0  5.72  5.75  3.62   3036
# 193571   0.34    3      1        3   62.9   55.0  4.45  4.49  2.81    681
# 193572   0.71    2      2        2   60.8   64.0  5.73  5.71  3.48   2258
#
# [193573 rows x 10 columns]
